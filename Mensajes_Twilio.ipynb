# %% [markdown]
# <img src=https://i.ytimg.com/vi/knxlmCVFAZI/maxresdefault.jpg>

# %%
#!pip install twilio

# %%
import os
from twilio.rest import Client
from twilio_config import *
import time

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


import pandas as pd
import requests
from bs4  import BeautifulSoup
from tqdm import tqdm

from datetime import datetime

# %% [markdown]
# # Armado de la URL

# %%
query = 'Bogotá'
api_key = API_KEY_WAPI

url_clima = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+'&days=1&aqi=no&alerts=no'
url_clima
# Out:
# 'http://api.weatherapi.com/v1/forecast.json?key=8bc74339800e46d5a78205958232903&q=Bogotá&days=1&aqi=no&alerts=no'

# %%
response = requests.get(url_clima).json()

# %%
response
# Out:
# {'location': {'name': 'Bogotá',
#   'region': 'Cundinamarca',
#   'country': 'Kolumbien',
#   'lat': 4.6,
#   'lon': -74.08,
#   'tz_id': 'America/Bogota',
#   'localtime_epoch': 1680204325,
#   'localtime': '2023-03-30 14:25'},
#  'current': {'last_updated_epoch': 1680203700,
#   'last_updated': '2023-03-30 14:15',
#   'temp_c': 18.0,
#   'temp_f': 64.4,
#   'is_day': 1,
#   'condition': {'text': 'Partly cloudy',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#    'code': 1003},
#   'wind_mph': 4.3,
#   'wind_kph': 6.8,
#   'wind_degree': 120,
#   'wind_dir': 'ESE',
#   'pressure_mb': 1025.0,
#   'pressure_in': 30.27,
#   'precip_mm': 0.4,
#   'precip_in': 0.02,
#   'humidity': 60,
#   'cloud': 50,
#   'feelslike_c': 18.0,
#   'feelslike_f': 64.4,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 4.0,
#   'gust_mph': 4.3,
#   'gust_kph': 6.8},
#  'forecast': {'forecastday': [{'date': '2023-03-30',
#     'date_epoch': 1680134400,
#     'day': {'maxtemp_c': 18.3,
#      'maxtemp_f': 64.9,
#      'mintemp_c': 10.0,
#      'mintemp_f': 50.0,
#      'avgtemp_c': 13.5,
#      'avgtemp_f': 56.2,
#      'maxwind_mph': 4.0,
#      'maxwind_kph': 6.5,
#      'totalprecip_mm': 3.1,
#      'totalprecip_in': 0.12,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 9.9,
#      'avgvis_miles': 6.0,
#      'avghumidity': 82.0,
#      'daily_will_it_rain': 1,
#      'daily_chance_of_rain': 88,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Patchy rain possible',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#       'code': 1063},
#      'uv': 3.0},
#     'astro': {'sunrise': '05:56 AM',
#      'sunset': '06:05 PM',
#      'moonrise': '01:21 PM',
#      'moonset': '01:14 AM',
#      'moon_phase': 'Waxing Gibbous',
#      'moon_illumination': '58',
#      'is_moon_up': 1,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1680152400,
#       'time': '2023-03-30 00:00',
#       'temp_c': 10.6,
#       'temp_f': 51.1,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 124,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 55,
#       'feelslike_c': 10.5,
#       'feelslike_f': 50.9,
#       'windchill_c': 10.5,
#       'windchill_f': 50.9,
#       'heatindex_c': 10.6,
#       'heatindex_f': 51.1,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 68,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 1.0},
#      {'time_epoch': 1680156000,
#       'time': '2023-03-30 01:00',
#       'temp_c': 10.5,
#       'temp_f': 50.9,
#       'is_day': 0,
#       'condition': {'text': 'Light rain shower',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/353.png',
#        'code': 1240},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 128,
#       'wind_dir': 'SE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 93,
#       'cloud': 53,
#       'feelslike_c': 10.5,
#       'feelslike_f': 50.9,
#       'windchill_c': 10.5,
#       'windchill_f': 50.9,
#       'heatindex_c': 10.5,
#       'heatindex_f': 50.9,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 1,
#       'chance_of_rain': 79,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 1.0},
#      {'time_epoch': 1680159600,
#       'time': '2023-03-30 02:00',
#       'temp_c': 10.4,
#       'temp_f': 50.7,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 130,
#       'wind_dir': 'SE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 93,
#       'cloud': 52,
#       'feelslike_c': 10.4,
#       'feelslike_f': 50.7,
#       'windchill_c': 10.4,
#       'windchill_f': 50.7,
#       'heatindex_c': 10.4,
#       'heatindex_f': 50.7,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 1.0},
#      {'time_epoch': 1680163200,
#       'time': '2023-03-30 03:00',
#       'temp_c': 10.2,
#       'temp_f': 50.4,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 123,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 52,
#       'feelslike_c': 10.2,
#       'feelslike_f': 50.4,
#       'windchill_c': 10.2,
#       'windchill_f': 50.4,
#       'heatindex_c': 10.2,
#       'heatindex_f': 50.4,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.3,
#       'gust_kph': 6.8,
#       'uv': 1.0},
#      {'time_epoch': 1680166800,
#       'time': '2023-03-30 04:00',
#       'temp_c': 10.0,
#       'temp_f': 50.0,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 119,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 52,
#       'feelslike_c': 9.9,
#       'feelslike_f': 49.8,
#       'windchill_c': 9.9,
#       'windchill_f': 49.8,
#       'heatindex_c': 10.0,
#       'heatindex_f': 50.0,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.2,
#       'will_it_rain': 1,
#       'chance_of_rain': 78,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.6,
#       'uv': 1.0},
#      {'time_epoch': 1680170400,
#       'time': '2023-03-30 05:00',
#       'temp_c': 10.1,
#       'temp_f': 50.2,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 115,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 54,
#       'feelslike_c': 9.8,
#       'feelslike_f': 49.6,
#       'windchill_c': 9.8,
#       'windchill_f': 49.6,
#       'heatindex_c': 10.1,
#       'heatindex_f': 50.2,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.4,
#       'gust_kph': 8.6,
#       'uv': 1.0},
#      {'time_epoch': 1680174000,
#       'time': '2023-03-30 06:00',
#       'temp_c': 10.2,
#       'temp_f': 50.4,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 3.1,
#       'wind_kph': 5.0,
#       'wind_degree': 114,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 94,
#       'cloud': 51,
#       'feelslike_c': 10.0,
#       'feelslike_f': 50.0,
#       'windchill_c': 10.0,
#       'windchill_f': 50.0,
#       'heatindex_c': 10.2,
#       'heatindex_f': 50.4,
#       'dewpoint_c': 9.2,
#       'dewpoint_f': 48.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 4.0},
#      {'time_epoch': 1680177600,
#       'time': '2023-03-30 07:00',
#       'temp_c': 11.4,
#       'temp_f': 52.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 119,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 90,
#       'cloud': 72,
#       'feelslike_c': 11.4,
#       'feelslike_f': 52.5,
#       'windchill_c': 11.4,
#       'windchill_f': 52.5,
#       'heatindex_c': 11.4,
#       'heatindex_f': 52.5,
#       'dewpoint_c': 9.8,
#       'dewpoint_f': 49.6,
#       'will_it_rain': 1,
#       'chance_of_rain': 74,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 3.0},
#      {'time_epoch': 1680181200,
#       'time': '2023-03-30 08:00',
#       'temp_c': 13.2,
#       'temp_f': 55.8,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 128,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 81,
#       'cloud': 64,
#       'feelslike_c': 13.6,
#       'feelslike_f': 56.5,
#       'windchill_c': 13.6,
#       'windchill_f': 56.5,
#       'heatindex_c': 13.2,
#       'heatindex_f': 55.8,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 50.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 3.0},
#      {'time_epoch': 1680184800,
#       'time': '2023-03-30 09:00',
#       'temp_c': 15.1,
#       'temp_f': 59.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 140,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 72,
#       'cloud': 31,
#       'feelslike_c': 15.1,
#       'feelslike_f': 59.2,
#       'windchill_c': 15.1,
#       'windchill_f': 59.2,
#       'heatindex_c': 15.1,
#       'heatindex_f': 59.2,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.4,
#       'gust_kph': 5.4,
#       'uv': 5.0},
#      {'time_epoch': 1680188400,
#       'time': '2023-03-30 10:00',
#       'temp_c': 16.9,
#       'temp_f': 62.4,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 148,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 87,
#       'feelslike_c': 16.9,
#       'feelslike_f': 62.4,
#       'windchill_c': 16.9,
#       'windchill_f': 62.4,
#       'heatindex_c': 16.9,
#       'heatindex_f': 62.4,
#       'dewpoint_c': 10.1,
#       'dewpoint_f': 50.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 64,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.8,
#       'gust_kph': 6.1,
#       'uv': 4.0},
#      {'time_epoch': 1680192000,
#       'time': '2023-03-30 11:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 157,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 62,
#       'cloud': 17,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'dewpoint_c': 10.9,
#       'dewpoint_f': 51.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.0,
#       'gust_kph': 6.5,
#       'uv': 5.0},
#      {'time_epoch': 1680195600,
#       'time': '2023-03-30 12:00',
#       'temp_c': 18.3,
#       'temp_f': 64.9,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 162,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 64,
#       'cloud': 89,
#       'feelslike_c': 18.3,
#       'feelslike_f': 64.9,
#       'windchill_c': 18.3,
#       'windchill_f': 64.9,
#       'heatindex_c': 18.3,
#       'heatindex_f': 64.9,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 86,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 4.0},
#      {'time_epoch': 1680199200,
#       'time': '2023-03-30 13:00',
#       'temp_c': 18.2,
#       'temp_f': 64.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 155,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 65,
#       'cloud': 16,
#       'feelslike_c': 18.2,
#       'feelslike_f': 64.8,
#       'windchill_c': 18.2,
#       'windchill_f': 64.8,
#       'heatindex_c': 18.2,
#       'heatindex_f': 64.8,
#       'dewpoint_c': 11.6,
#       'dewpoint_f': 52.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 5.0},
#      {'time_epoch': 1680202800,
#       'time': '2023-03-30 14:00',
#       'temp_c': 17.5,
#       'temp_f': 63.5,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 157,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.9,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 69,
#       'cloud': 86,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.5,
#       'windchill_c': 17.5,
#       'windchill_f': 63.5,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.5,
#       'dewpoint_c': 11.8,
#       'dewpoint_f': 53.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 64,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 4.3,
#       'gust_kph': 6.8,
#       'uv': 4.0},
#      {'time_epoch': 1680206400,
#       'time': '2023-03-30 15:00',
#       'temp_c': 17.5,
#       'temp_f': 63.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 154,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 70,
#       'cloud': 21,
#       'feelslike_c': 17.5,
#       'feelslike_f': 63.5,
#       'windchill_c': 17.5,
#       'windchill_f': 63.5,
#       'heatindex_c': 17.5,
#       'heatindex_f': 63.5,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 5.0},
#      {'time_epoch': 1680210000,
#       'time': '2023-03-30 16:00',
#       'temp_c': 17.4,
#       'temp_f': 63.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 163,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1012.0,
#       'pressure_in': 29.88,
#       'precip_mm': 1.2,
#       'precip_in': 0.05,
#       'humidity': 71,
#       'cloud': 84,
#       'feelslike_c': 17.4,
#       'feelslike_f': 63.3,
#       'windchill_c': 17.4,
#       'windchill_f': 63.3,
#       'heatindex_c': 17.4,
#       'heatindex_f': 63.3,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.8,
#       'will_it_rain': 1,
#       'chance_of_rain': 88,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 4.9,
#       'gust_kph': 7.9,
#       'uv': 4.0},
#      {'time_epoch': 1680213600,
#       'time': '2023-03-30 17:00',
#       'temp_c': 16.3,
#       'temp_f': 61.3,
#       'is_day': 1,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 164,
#       'wind_dir': 'SSE',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.91,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 76,
#       'cloud': 27,
#       'feelslike_c': 16.3,
#       'feelslike_f': 61.3,
#       'windchill_c': 16.3,
#       'windchill_f': 61.3,
#       'heatindex_c': 16.3,
#       'heatindex_f': 61.3,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 3.1,
#       'gust_kph': 5.0,
#       'uv': 5.0},
#      {'time_epoch': 1680217200,
#       'time': '2023-03-30 18:00',
#       'temp_c': 13.5,
#       'temp_f': 56.3,
#       'is_day': 1,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#        'code': 1063},
#       'wind_mph': 2.5,
#       'wind_kph': 4.0,
#       'wind_degree': 141,
#       'wind_dir': 'SE',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.4,
#       'precip_in': 0.02,
#       'humidity': 87,
#       'cloud': 77,
#       'feelslike_c': 14.0,
#       'feelslike_f': 57.2,
#       'windchill_c': 14.0,
#       'windchill_f': 57.2,
#       'heatindex_c': 13.5,
#       'heatindex_f': 56.3,
#       'dewpoint_c': 11.4,
#       'dewpoint_f': 52.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 63,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 9.0,
#       'vis_miles': 5.0,
#       'gust_mph': 3.6,
#       'gust_kph': 5.8,
#       'uv': 3.0},
#      {'time_epoch': 1680220800,
#       'time': '2023-03-30 19:00',
#       'temp_c': 13.2,
#       'temp_f': 55.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 130,
#       'wind_dir': 'SE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 22,
#       'feelslike_c': 13.2,
#       'feelslike_f': 55.8,
#       'windchill_c': 13.2,
#       'windchill_f': 55.8,
#       'heatindex_c': 13.2,
#       'heatindex_f': 55.8,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.6,
#       'uv': 1.0},
#      {'time_epoch': 1680224400,
#       'time': '2023-03-30 20:00',
#       'temp_c': 11.3,
#       'temp_f': 52.3,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 136,
#       'wind_dir': 'SE',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 90,
#       'cloud': 83,
#       'feelslike_c': 11.4,
#       'feelslike_f': 52.5,
#       'windchill_c': 11.4,
#       'windchill_f': 52.5,
#       'heatindex_c': 11.3,
#       'heatindex_f': 52.3,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 1,
#       'chance_of_rain': 85,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.2,
#       'uv': 1.0},
#      {'time_epoch': 1680228000,
#       'time': '2023-03-30 21:00',
#       'temp_c': 11.1,
#       'temp_f': 52.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 132,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 23,
#       'feelslike_c': 11.1,
#       'feelslike_f': 52.0,
#       'windchill_c': 11.1,
#       'windchill_f': 52.0,
#       'heatindex_c': 11.1,
#       'heatindex_f': 52.0,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 48.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.7,
#       'gust_kph': 7.6,
#       'uv': 1.0},
#      {'time_epoch': 1680231600,
#       'time': '2023-03-30 22:00',
#       'temp_c': 11.0,
#       'temp_f': 51.8,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain possible',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 130,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.06,
#       'precip_mm': 0.1,
#       'precip_in': 0.0,
#       'humidity': 89,
#       'cloud': 71,
#       'feelslike_c': 10.7,
#       'feelslike_f': 51.3,
#       'windchill_c': 10.7,
#       'windchill_f': 51.3,
#       'heatindex_c': 11.0,
#       'heatindex_f': 51.8,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 60,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.8,
#       'gust_kph': 9.4,
#       'uv': 1.0},
#      {'time_epoch': 1680235200,
#       'time': '2023-03-30 23:00',
#       'temp_c': 11.1,
#       'temp_f': 52.0,
#       'is_day': 0,
#       'condition': {'text': 'Partly cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#        'code': 1003},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 123,
#       'wind_dir': 'ESE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'humidity': 88,
#       'cloud': 48,
#       'feelslike_c': 10.8,
#       'feelslike_f': 51.4,
#       'windchill_c': 10.8,
#       'windchill_f': 51.4,
#       'heatindex_c': 11.1,
#       'heatindex_f': 52.0,
#       'dewpoint_c': 9.1,
#       'dewpoint_f': 48.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.6,
#       'gust_kph': 9.0,
#       'uv': 1.0}]}]}}

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
len(response['forecast']['forecastday'][0]['hour'])
# Out:
# 24

# %% [markdown]
# ### Fecha

# %%
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[0]
# Out:
# '2023-03-30'

# %% [markdown]
# ### Hora

# %%
int(response['forecast']['forecastday'][0]['hour'][0]['time'].split()[1].split(':')[0])
# Out:
# 0

# %% [markdown]
# ### Condición

# %%
response['forecast']['forecastday'][0]['hour'][0]['condition']['text']
# Out:
# 'Patchy rain possible'

# %% [markdown]
# ### Temperatura

# %%
response['forecast']['forecastday'][0]['hour'][0]['temp_c']

# %%
response['forecast']['forecastday'][0]['hour'][0]['will_it_rain']
# Out:
# 0

# %%
response['forecast']['forecastday'][0]['hour'][2]['chance_of_rain']
# Out:
# 0

# %% [markdown]
# # Dataframe

# %%
def get_forecast(response,i):
    
    fecha = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hora = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condicion = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    tempe = float(recoresponserd['forecast']['forecastday'][0]['hour'][i]['temp_c'])
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']
    
    return fecha,hora,condicion,tempe,rain,prob_rain

# %%
datos = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])),colour = 'green'):
    
    datos.append(get_forecast(response,i))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 114260.27it/s]

# %%
datos[0]
# Out:
# ('2022-09-15', 0, 'Partly cloudy', 8.6, 0, 0)

# %%
col = ['Fecha','Hora','Condicion','Temperatura','Lluvia','prob_lluvia']
df = pd.DataFrame(datos,columns=col)
df = df.sort_values(by = 'Hora',ascending = True)
df
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  prob_lluvia
# 0   2022-09-15     0         Partly cloudy          8.6       0            0
# 1   2022-09-15     1  Patchy rain possible          8.4       0           60
# 2   2022-09-15     2         Partly cloudy          8.6       0            0
# 3   2022-09-15     3         Partly cloudy          8.5       0            0
# 4   2022-09-15     4         Partly cloudy          8.4       0            0
# 5   2022-09-15     5         Partly cloudy          8.1       0            0
# 6   2022-09-15     6         Partly cloudy          8.4       0            0
# 7   2022-09-15     7                 Sunny         12.1       0            0
# 8   2022-09-15     8                 Sunny         14.8       0            0
# 9   2022-09-15     9                 Sunny         17.2       0            0
# 10  2022-09-15    10                 Sunny         19.4       0            0
# 11  2022-09-15    11                 Sunny         21.0       0            0
# 12  2022-09-15    12  Patchy rain possible         19.8       0           60
# 13  2022-09-15    13                 Sunny         19.3       0            0
# 14  2022-09-15    14  Patchy rain possible         19.8       1           94
# 15  2022-09-15    15                 Sunny         18.7       0            0
# 16  2022-09-15    16  Patchy rain possible         18.5       1           88
# 17  2022-09-15    17                 Sunny         17.2       0            0
# 18  2022-09-15    18  Patchy rain possible         12.9       0           70
# 19  2022-09-15    19         Partly cloudy         11.4       0            0
# 20  2022-09-15    20         Partly cloudy         10.5       0            0
# 21  2022-09-15    21         Partly cloudy          9.7       0            0
# 22  2022-09-15    22         Partly cloudy          9.6       0            0
# 23  2022-09-15    23         Partly cloudy          9.5       0            0

# %%
# data_cli = {
#     'Fecha':datos[0][0],
#     'Hora':datos[1][],
#     'Tiempo':condicion,
#     'Temperatura':tempe,
#     'LLoverá':rain,
#     'prob_lluvia':prob_rain
    
# }

# df = pd.DataFrame(data_cli)
# df = df.sort_values(by = 'Hora',ascending = True)

# %%
df[df['Lluvia']==1]
# Out:
#          Fecha  Hora             Condicion  Temperatura  Lluvia  prob_lluvia
# 14  2022-09-15    14  Patchy rain possible         19.8       1           94
# 16  2022-09-15    16  Patchy rain possible         18.5       1           88

# %%
df_rain =  df[(df['Lluvia']==1) & (df['Hora']>6) & (df['Hora']< 22)]
df_rain = df_rain[['Hora','Condicion']]
df_rain.set_index('Hora', inplace = True)

# %%
df['Fecha'][0]
# Out:
# '2022-09-15'

# %%
df_rain
# Out:
#                  Condicion
# Hora
# 14    Patchy rain possible
# 16    Patchy rain possible

# %%
'\nHola! \n\n\n El pronostico del tiempo hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain)
# Out:
# '\nHola! \n\n\n El pronostico del tiempo hoy 2022-09-15 en Bogotá es : \n\n\n                  Condicion\nHora                      \n14    Patchy rain possible\n16    Patchy rain possible'

# %%
PHONE_NUMBER
# Out:
# '+1 614 401 3161'

# %% [markdown]
# # Mensaje SMS desde Twilio

# %%
time.sleep(2)
account_sid = TWILIO_ACCOUNT_SID 
auth_token = TWILIO_AUTH_TOKEN

client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                     body='\nHola! \n\n\n El pronostico de lluvia hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain),
                     from_=PHONE_NUMBER,
                     to='+573222007879'
                 )

print('Mensaje Enviado ' + message.sid)
# Out:
# Mensaje Enviado SMbc309ab2afc09ea1f87a7eb64fb8fdda

# %% [markdown]
# # Challenge
#
# * Extrae el valor del dolar en tu país y el top 10 de criptomonedas con su respectiva valoración
# * Ahora envia un mensaje diarío a tu Whatsapp usando Twilio
#
# **hint 💡** Investiga que API's gratuitas existen para consultar estos datos
#
#
#
# <img src="WhatsApp Image 2022-09-13 at 9.12.18 AM.jpeg" width="200" height="200" />
